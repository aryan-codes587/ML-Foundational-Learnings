# %% [markdown]
# ### ETL (Extract Transform load)
# - Load the data from aws.
# - Apply Transformation on the loaded data.
# - Make a new DB on AWS.
# - Upload data on AWS DB.

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.coonect('host = ')
