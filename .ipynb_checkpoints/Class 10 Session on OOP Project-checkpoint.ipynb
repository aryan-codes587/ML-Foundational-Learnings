# %% [markdown]
# d9f279dfe98de4a4710817bcc7143b760d79f0af

# %%
# !pip install nlpcloud
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "d9f279dfe98de4a4710817bcc7143b760d79f0af", gpu=True)
client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)
# Out:
# ...
# {'entities': [{'start': 26,
#    'end': 36,
#    'type': 'programming languages',
#    'text': 'Javascript'},
#   {'start': 102,
#    'end': 108,
#    'type': 'programming languages',
#    'text': 'Python'},
#   {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %% [markdown]
# Hello How would yo like to process
# - Register
#        - Name
#        - Login
#        - Password
# - Login
#        - Hi
#        - NER
#        - Lang detection
#        - Sentiment analysis
#        - Logout

# %%
class NLPApp:
    def __init__(self):
        self.__database = {}
        self.__first_menu()

    def __first_menu(self):
        first_input = input("""
        Hi! how would you like to proceed?
        1. Not a member? Register
        2. Already a member? Login
        3. Galti se aa gaye? Exit
        """)

        if first_input == 1:
            self.__register()
        elif first_input == 2:
            self.__login()
        else:
            exit()

    def __second_menu(self):
        second_input = input("""
        Hi! how would you like to proceed?
        1. NER
        2. Language Detection
        3. Sentiment Analysis
        4. Logout
        """)
    
        if second_input == '1':
          self.__ner()
        elif second_input == '2':
          self.__language_detection()
        elif second_input == '3':
          self.__sentiment_analysis()
        else:
          exit()

    def __register(self):
        name = input('enter name')
        email = input('enter email')
        password = input('enter password')

        if email in database:
            print('Email already Exists')
        else :
            self.__database[email] = [name,password]
            print('Registration succesffull')
            print(self.__database)
            self.first_menu()
            

    def __login(self):
        email = input('enter email')
        password = input('enter password')

        if email not in database:
            print('No user found please register first')
            self.first_menu()
        else:
            if self.__database[1] == password:
                print('Login successfull')
                self.__secound_menu()
            else :
                print('wrong password try again')
                self.__login()

    def __ner(self):
        para = input('Enter the paragraph')
        search_term = input('What would you like to search')

        client = nlpcloud.Client("gpt-oss-120b", "d9f279dfe98de4a4710817bcc7143b760d79f0af", gpu=True)
        response = client.entities(
            para,
            searched_entity=search_term
        )

# %%
obj = NLPApp()
# Out:
#         Hi! how would you like to proceed?
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Galti se aa gaye? Exit
#          1
