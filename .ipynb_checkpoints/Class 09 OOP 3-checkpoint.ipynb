# %% [markdown]
# ## Class Relationship
# - Aggregation
# ![image.png](attachment:91fc08a1-a588-46ee-99f1-65edc167db65.png)
#
# - Inheritance

# %% [markdown]
# ### **Aggregation (Has A Relationship)**

# %%
class Address:
    def __init__(self,city,pin,state):
        self.city = city
        self.pin = pin
        self.state = state
        
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_add(self):
        print(self.address.city , self.address.pin, self.address.state)

# %%
add1 = Address('gurgaon',122011 , 'haryana')
cust = Customer('nitish','male',add1)
print(cust.address)
print(cust.address.city)
cust.print_add()
# Out:
# ...
# gurgaon
# gurgaon 122011 haryana

# %%
class Address:
    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state

    def get_city(self):
        return self.__city

    def edit_add(self,new_city, new_pin, new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state
        
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_add(self):
        print(self.address.get_city() , self.address.pin, self.address.state)

    def edit_details(self,new_name, new_city, new_pin, new_state):
        self.name = new_name
        self.address.edit_add(new_city , new_pin , new_state)

# %%
add1 = Address('gurgaon',122011 , 'haryana')
cust = Customer('nitish','male',add1)
cust.print_add() # Error :- 'Address' object has no attribute 'city'
# Out:
# gurgaon 122011 haryana

# %%
cust.print_add()
cust.edit_details('shreya','mumbai',111111,'maharastra')
cust.print_add()
# Out:
# gurgaon 122011 haryana
# mumbai 111111 maharastra

# %% [markdown]
# ### Points to remember :-
# - In Aggregation the owener class (Here Customer) cannot access private variables/attributes of the owened class (Here Address).

# %% [markdown]
# ### Inheritance
# - What is inheritance
#     - Inheritance lets a new class (the child) reuse attributes and methods from an existing class (the parent). It reduces duplicate code and builds a natural hierarchy (e.g., Animal → Dog).
#
# - Example
# - What gets inherited?
#
# ![image.png](attachment:760acf08-136b-4b07-a049-2066253ae4e1.png)
# ![image.png](attachment:e140ff3b-ad62-4de2-a400-d9760853a853.png)

# %%
# Inheritance and it's benifits

# %%
# Example
class User:
    def __init__(self):
        self.name = 'nitish'

    def login(self):
        print('login')

class Student(User):
    def enroll(self):
        print('Enroll into the course')

u = User()
s = Student()

print(s.name)
s.enroll()
s.login()
# Out:
# nitish
# Enroll into the course
# login

# %%
# Class Diagram

# %% [markdown]
# **What gets inherited** :-
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %% [markdown]
# - If child doesn't have it's own constructor then it goes looking for one in parent's class for constructor

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
# s.brand # ttributeError: 'SmartPhone' object has no attribute 'brand'
# Out:
# Inside SmartPhone constructor

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)


s=SmartPhone(20000, "Apple", 13)
s.show()
# Out:
# Inside phone constructor
# 20000

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")
        
son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 18
#      15         return self.__val
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:",son.get_val())
#
# Cell In[67], line 7, in Parent.get_num(self)
#       6 def get_num(self):
# ----> 7     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self): # Method is overriden as child already has it's own buy() function
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent's buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print('Inside phone Constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self,price, brand, camera, os, ram):
        super().__init__(price,brand,camera)
        self.os = os
        self.ram = ram
        print('Inside Smartphone Constructor')

s = SmartPhone(20000, 'Samsung', 13, 'Android', 2)
# Out:
# Inside phone Constructor
# Inside Smartphone Constructor

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s = SmartPhone(1000,"Apple","13px")
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %% [markdown]
# ![image.png](attachment:b5c4fdb7-a0fd-48fa-ae59-841e380cc2b1.png)

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=super().m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# 70

# %% [markdown]
# ## Polymorphishm :-
# - Method Overriding
# - Method Overloading
# - Operator Overloading
# - Method Overloading doesn't work in python. It's overidden by last method of same name

# %%
class Shape:
    def area(self, radius):
        return 3.14 * radius * radius

    def area(self,l,b):
        return l*b

s = Shape()
# s.area(2) 
s.area(2,3)
# Out:
# 6

# %% [markdown]
# ## Abstraction :-

# %%
from abc import ABC, abstractmethod
class BankApp(ABC):
    def database(self):
        print('connected to database')
    
    
    @abstractmethod
    def security(self):
        pass

# %%
class Mobile(BankApp):
    def mobile_login(self):
        print('Login into mobile')

    def security(self):
        print('Mobile Security')

# %%
mob = Mobile()
