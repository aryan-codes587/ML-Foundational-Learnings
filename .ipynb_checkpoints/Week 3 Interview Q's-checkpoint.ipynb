# %% [markdown]
# - How indexing works in sets
# - Whydictkeycantbemutabledatatypes
# - Enumerate
# - destructor
# - dir/isinstance/issubclass
# - classmethodvsstaticmethod
# - Thediamondproblem
# - What’sthemeaningofsingleanddoubleunderscoresinPythonvariableandmethodnames
# - MagicMethods(reprvsstr)
# - Howcanobjectsbestoredinsetseventhoughtheyaremutable
